# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
number = 0
sets = 1
data = {}

# set up initial message
print(f"Beginning Data Retrieval")
print("-------------------------")

# Build query URL
for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    number = number + 1
    
    if number == 50:
        sets = sets+1
        number = 1
        
    try:
        print(f"Processing Record {number} of Set {sets} | {city}")
       
    except:
        print("City not found. Skipping ...")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | hambantota
# Processing Record 2 of Set 1 | verkhnyaya sinyachikha
# Processing Record 3 of Set 1 | progreso
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kadykchan
# Processing Record 7 of Set 1 | gulshat
# Processing Record 8 of Set 1 | nizhneyansk
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | taolanaro
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | stabat
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | aykhal
# Processing Record 18 of Set 1 | barentsburg
# Processing Record 19 of Set 1 | morros
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | kraskino
# Processing Record 22 of Set 1 | illoqqortoormiut
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | samarai
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | hualmay
# Processing Record 28 of Set 1 | foligno
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | orcopampa
# Processing Record 32 of Set 1 | portland
# Processing Record 33 of Set 1 | shumyachi
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | madang
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | ponta delgada
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | walvis bay
# Processing Record 44 of Set 1 | kadiri
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | mzimba
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | ullapool
# Processing Record 1 of Set 2 | belaya gora
# Processing Record 2 of Set 2 | bosaso
# Processing Record 3 of Set 2 | luau
# Processing Record 4 of Set 2 | cap malheureux
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | larsnes
# Processing Record 8 of Set 2 | batsfjord
# Processing Record 9 of Set 2 | zachagansk
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | samalaeulu
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | ostrovnoy
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | elko
# Processing Record 21 of Set 2 | hailar
# Processing Record 22 of Set 2 | turukhansk
# Processing Record 23 of Set 2 | fairview
# Processing Record 24 of Set 2 | hay river
# Processing Record 25 of Set 2 | babanusah
# Processing Record 26 of Set 2 | paamiut
# Processing Record 27 of Set 2 | beian
# Processing Record 28 of Set 2 | nata
# Processing Record 29 of Set 2 | burica
# Processing Record 30 of Set 2 | cap-aux-meules
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | pontiac
# Processing Record 33 of Set 2 | pokrovsk
# Processing Record 34 of Set 2 | vaitupu
# Processing Record 35 of Set 2 | odweyne
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | tumannyy
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | blagoyevo
# Processing Record 40 of Set 2 | zarya
# Processing Record 41 of Set 2 | veraval
# Processing Record 42 of Set 2 | sentyabrskiy
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | marcona
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | hadejia
# Processing Record 49 of Set 2 | alugan
# Processing Record 1 of Set 3 | jiayuguan
# Processing Record 2 of Set 3 | rodez
# Processing Record 3 of Set 3 | sao felix do xingu
# Processing Record 4 of Set 3 | kaoma
# Processing Record 5 of Set 3 | fourmies
# Processing Record 6 of Set 3 | marakkanam
# Processing Record 7 of Set 3 | moron
# Processing Record 8 of Set 3 | takoradi
# Processing Record 9 of Set 3 | warora
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | amderma
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | moyale
# Processing Record 15 of Set 3 | waingapu
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | inirida
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | badajoz
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | kattivakkam
# Processing Record 25 of Set 3 | marabba
# Processing Record 26 of Set 3 | grindavik
# Processing Record 27 of Set 3 | ondorhaan
# Processing Record 28 of Set 3 | goderich
# Processing Record 29 of Set 3 | nyurba
# Processing Record 30 of Set 3 | iskateley
# Processing Record 31 of Set 3 | willowmore
# Processing Record 32 of Set 3 | fez
# Processing Record 33 of Set 3 | tatarka
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | san policarpo
# Processing Record 36 of Set 3 | chiredzi
# Processing Record 37 of Set 3 | san patricio
# Processing Record 38 of Set 3 | katobu
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | sioux lookout
# Processing Record 41 of Set 3 | samandag
# Processing Record 42 of Set 3 | kabanjahe
# Processing Record 43 of Set 3 | liaoyang
# Processing Record 44 of Set 3 | juifang
# Processing Record 45 of Set 3 | rudnaya pristan
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | zhezkazgan
# Processing Record 48 of Set 3 | hongjiang
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | xai-xai
# Processing Record 2 of Set 4 | northam
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | santiago del estero
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | isangel
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | berlevag
# Processing Record 9 of Set 4 | lanxi
# Processing Record 10 of Set 4 | saleaula
# Processing Record 11 of Set 4 | bandarbeyla
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | aksha
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | yertarskiy
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | paramonga
# Processing Record 19 of Set 4 | karaidel
# Processing Record 20 of Set 4 | acaponeta
# Processing Record 21 of Set 4 | limbang
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | srednekolymsk
# Processing Record 24 of Set 4 | nuevitas
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | cumana
# Processing Record 27 of Set 4 | chambar
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | luena
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | homer
# Processing Record 33 of Set 4 | copiapo
# Processing Record 34 of Set 4 | yulara
# Processing Record 35 of Set 4 | broken hill
# Processing Record 36 of Set 4 | attawapiskat
# Processing Record 37 of Set 4 | krasnoborsk
# Processing Record 38 of Set 4 | hammerfest
# Processing Record 39 of Set 4 | moose factory
# Processing Record 40 of Set 4 | bowmore
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | benesov nad ploucnici
# Processing Record 43 of Set 4 | umba
# Processing Record 44 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | awjilah
# Processing Record 47 of Set 4 | marzuq
# Processing Record 48 of Set 4 | fairbanks
# Processing Record 49 of Set 4 | pevek
# Processing Record 1 of Set 5 | fukue
# Processing Record 2 of Set 5 | paita
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | ciudad bolivar
# Processing Record 5 of Set 5 | warrington
# Processing Record 6 of Set 5 | la paz
# Processing Record 7 of Set 5 | westport
# Processing Record 8 of Set 5 | san giuseppe jato
# Processing Record 9 of Set 5 | komsomolskiy
# Processing Record 10 of Set 5 | abu zabad
# Processing Record 11 of Set 5 | emirdag
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | mergui
# Processing Record 14 of Set 5 | iralaya
# Processing Record 15 of Set 5 | mackay
# Processing Record 16 of Set 5 | shiraz
# Processing Record 17 of Set 5 | khonuu
# Processing Record 18 of Set 5 | dingle
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | shelekhov
# Processing Record 21 of Set 5 | ginda
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | gizo
# Processing Record 24 of Set 5 | tigil
# Processing Record 25 of Set 5 | rio grande
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | belushya guba
# Processing Record 28 of Set 5 | salo
# Processing Record 29 of Set 5 | paidha
# Processing Record 30 of Set 5 | saint-georges
# Processing Record 31 of Set 5 | ixtapa
# Processing Record 32 of Set 5 | thinadhoo
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | dibaya
# Processing Record 35 of Set 5 | gillette
# Processing Record 36 of Set 5 | fortuna
# Processing Record 37 of Set 5 | bubaque
# Processing Record 38 of Set 5 | usinsk
# Processing Record 39 of Set 5 | mao
# Processing Record 40 of Set 5 | nome
# Processing Record 41 of Set 5 | antofagasta
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | jeremie
# Processing Record 44 of Set 5 | lorengau
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | luanda
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 1 of Set 6 | bargal
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | buraydah
# Processing Record 4 of Set 6 | timmins
# Processing Record 5 of Set 6 | necochea
# Processing Record 6 of Set 6 | praia da vitoria
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | lipari
# Processing Record 9 of Set 6 | okhotsk
# Processing Record 10 of Set 6 | vanimo
# Processing Record 11 of Set 6 | waipawa
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | alakurtti
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | karratha
# Processing Record 16 of Set 6 | destin
# Processing Record 17 of Set 6 | smila
# Processing Record 18 of Set 6 | loreto
# Processing Record 19 of Set 6 | dolbeau
# Processing Record 20 of Set 6 | ballina
# Processing Record 21 of Set 6 | khasan
# Processing Record 22 of Set 6 | tsihombe
# Processing Record 23 of Set 6 | sefophe
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | gayny
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | nakskov
# Processing Record 28 of Set 6 | mayumba
# Processing Record 29 of Set 6 | fairfield
# Processing Record 30 of Set 6 | katherine
# Processing Record 31 of Set 6 | litoral del san juan
# Processing Record 32 of Set 6 | didsbury
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | pathein
# Processing Record 35 of Set 6 | nelidovo
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | iwaki
# Processing Record 39 of Set 6 | mount darwin
# Processing Record 40 of Set 6 | harbour breton
# Processing Record 41 of Set 6 | coos bay
# Processing Record 42 of Set 6 | aksarka
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | quang ngai
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | boyolangu
# Processing Record 47 of Set 6 | rognan
# Processing Record 48 of Set 6 | baghdad
# Processing Record 49 of Set 6 | wangqing
# Processing Record 1 of Set 7 | clyde river
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | hadrut
# Processing Record 4 of Set 7 | palabuhanratu
# Processing Record 5 of Set 7 | wladyslawowo
# Processing Record 6 of Set 7 | arraial do cabo
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | yanan
# Processing Record 9 of Set 7 | acajutla
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | gorno-chuyskiy
# Processing Record 12 of Set 7 | coahuayana
# Processing Record 13 of Set 7 | codrington
# Processing Record 14 of Set 7 | veinticinco de mayo
# Processing Record 15 of Set 7 | muisne
# Processing Record 16 of Set 7 | shahr-e babak
# Processing Record 17 of Set 7 | cam pha
# Processing Record 18 of Set 7 | sayan
# Processing Record 19 of Set 7 | marshall
# Processing Record 20 of Set 7 | salalah
# Processing Record 21 of Set 7 | provideniya
# Processing Record 22 of Set 7 | adrar
# Processing Record 23 of Set 7 | qurayyat
# Processing Record 24 of Set 7 | sumbe
# Processing Record 25 of Set 7 | beverley
# Processing Record 26 of Set 7 | kavaratti
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | manjacaze
# Processing Record 29 of Set 7 | bontang
# Processing Record 30 of Set 7 | ouango
# Processing Record 31 of Set 7 | plettenberg bay
# Processing Record 32 of Set 7 | mount isa
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | nanakuli
# Processing Record 35 of Set 7 | zaozerne
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | mys shmidta
# Processing Record 38 of Set 7 | sobolevo
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | christchurch
# Processing Record 41 of Set 7 | lompoc
# Processing Record 42 of Set 7 | san quintin
# Processing Record 43 of Set 7 | sinnamary
# Processing Record 44 of Set 7 | batemans bay
# Processing Record 45 of Set 7 | umm lajj
# Processing Record 46 of Set 7 | kahului
# Processing Record 47 of Set 7 | vestmanna
# Processing Record 48 of Set 7 | neuquen
# Processing Record 49 of Set 7 | kaitangata
# Processing Record 1 of Set 8 | crailsheim
# Processing Record 2 of Set 8 | gazanjyk
# Processing Record 3 of Set 8 | shimoda
# Processing Record 4 of Set 8 | palmer
# Processing Record 5 of Set 8 | merauke
# Processing Record 6 of Set 8 | saldanha
# Processing Record 7 of Set 8 | montego bay
# Processing Record 8 of Set 8 | hovd
# Processing Record 9 of Set 8 | bur gabo
# Processing Record 10 of Set 8 | port moresby
# Processing Record 11 of Set 8 | outram
# Processing Record 12 of Set 8 | mihaesti
# Processing Record 13 of Set 8 | conceicao do mato dentro
# Processing Record 14 of Set 8 | masallatah
# Processing Record 15 of Set 8 | edd
# Processing Record 16 of Set 8 | hasaki
# Processing Record 17 of Set 8 | grand river south east
# Processing Record 18 of Set 8 | yenagoa
# Processing Record 19 of Set 8 | ambunti
# Processing Record 20 of Set 8 | loma alta
# Processing Record 21 of Set 8 | padang
# Processing Record 22 of Set 8 | vostok
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | pundaguitan
# Processing Record 25 of Set 8 | cayenne
# Processing Record 26 of Set 8 | toora-khem
# Processing Record 27 of Set 8 | mana
# Processing Record 28 of Set 8 | kolpashevo
# Processing Record 29 of Set 8 | talnakh
# Processing Record 30 of Set 8 | hithadhoo
# Processing Record 31 of Set 8 | totness
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | honiara
# Processing Record 34 of Set 8 | touros
# Processing Record 35 of Set 8 | naliya
# Processing Record 36 of Set 8 | husavik
# Processing Record 37 of Set 8 | ornskoldsvik
# Processing Record 38 of Set 8 | pemba
# Processing Record 39 of Set 8 | samastipur
# Processing Record 40 of Set 8 | lubao
# Processing Record 41 of Set 8 | higuey
# Processing Record 42 of Set 8 | morehead
# Processing Record 43 of Set 8 | yirol
# Processing Record 44 of Set 8 | puerto madero
# Processing Record 45 of Set 8 | lerwick
# Processing Record 46 of Set 8 | sonamukhi
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | kijang
# Processing Record 49 of Set 8 | marfino
# Processing Record 1 of Set 9 | panaba
# Processing Record 2 of Set 9 | jamame
# Processing Record 3 of Set 9 | tessalit
# Processing Record 4 of Set 9 | quzhou
# Processing Record 5 of Set 9 | svetlaya
# Processing Record 6 of Set 9 | henties bay
# Processing Record 7 of Set 9 | maxixe
# Processing Record 8 of Set 9 | port lincoln
# Processing Record 9 of Set 9 | nokaneng
# Processing Record 10 of Set 9 | kununurra
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | camapua
# Processing Record 13 of Set 9 | cockburn town
# Processing Record 14 of Set 9 | nizhnevartovsk
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | myskhako
# Processing Record 17 of Set 9 | riachao das neves
# Processing Record 18 of Set 9 | patur
# Processing Record 19 of Set 9 | riohacha
# Processing Record 20 of Set 9 | erdaojiang
# Processing Record 21 of Set 9 | humen
# Processing Record 22 of Set 9 | neijiang
# Processing Record 23 of Set 9 | slave lake
# Processing Record 24 of Set 9 | harstad
# Processing Record 25 of Set 9 | suffolk
# Processing Record 26 of Set 9 | visnes
# Processing Record 27 of Set 9 | is
# Processing Record 28 of Set 9 | kamaishi
# Processing Record 29 of Set 9 | cherskiy
# Processing Record 30 of Set 9 | sarangani
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | chara
# Processing Record 33 of Set 9 | rungata
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | kishtwar
# Processing Record 36 of Set 9 | egvekinot
# Processing Record 37 of Set 9 | normandin
# Processing Record 38 of Set 9 | carlagan
# Processing Record 39 of Set 9 | lincoln
# Processing Record 40 of Set 9 | yudong
# Processing Record 41 of Set 9 | thaba nchu
# Processing Record 42 of Set 9 | chaman
# Processing Record 43 of Set 9 | tiarei
# Processing Record 44 of Set 9 | ratanpur
# Processing Record 45 of Set 9 | canberra
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | tucuman
# Processing Record 48 of Set 9 | hornepayne
# Processing Record 49 of Set 9 | belfast
# Processing Record 1 of Set 10 | camopi
# Processing Record 2 of Set 10 | grajau
# Processing Record 3 of Set 10 | nancha
# Processing Record 4 of Set 10 | baykit
# Processing Record 5 of Set 10 | byron bay
# Processing Record 6 of Set 10 | altay
# Processing Record 7 of Set 10 | lazaro cardenas
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | rybnik
# Processing Record 10 of Set 10 | qasigiannguit
# Processing Record 11 of Set 10 | vila franca do campo
# Processing Record 12 of Set 10 | guerrero negro
# Processing Record 13 of Set 10 | valparaiso
# Processing Record 14 of Set 10 | lagos
# Processing Record 15 of Set 10 | lima
# Processing Record 16 of Set 10 | los llanos de aridane
# Processing Record 17 of Set 10 | faanui
# Processing Record 18 of Set 10 | hobyo
# Processing Record 19 of Set 10 | namie
# Processing Record 20 of Set 10 | bela
# Processing Record 21 of Set 10 | san luis
# Processing Record 22 of Set 10 | lakes entrance
# Processing Record 23 of Set 10 | jiangyou
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | inongo
# Processing Record 26 of Set 10 | bay roberts
# Processing Record 27 of Set 10 | labuhan
# Processing Record 28 of Set 10 | safranbolu
# Processing Record 29 of Set 10 | butterworth
# Processing Record 30 of Set 10 | tieling
# Processing Record 31 of Set 10 | leningradskiy
# Processing Record 32 of Set 10 | nanortalik
# Processing Record 33 of Set 10 | aswan
# Processing Record 34 of Set 10 | trimbak
# Processing Record 35 of Set 10 | barkly west
# Processing Record 36 of Set 10 | belmonte
# Processing Record 37 of Set 10 | hami
# Processing Record 38 of Set 10 | hofn
# Processing Record 39 of Set 10 | minudasht
# Processing Record 40 of Set 10 | shingu
# Processing Record 41 of Set 10 | wlingi
# Processing Record 42 of Set 10 | guangyuan
# Processing Record 43 of Set 10 | pingdingshan
# Processing Record 44 of Set 10 | colomi
# Processing Record 45 of Set 10 | kintampo
# Processing Record 46 of Set 10 | maneadero
# Processing Record 47 of Set 10 | polewali
# Processing Record 48 of Set 10 | sesimbra
# Processing Record 49 of Set 10 | bazpur
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | bayshore gardens
# Processing Record 3 of Set 11 | revelstoke
# Processing Record 4 of Set 11 | vila
# Processing Record 5 of Set 11 | mount gambier
# Processing Record 6 of Set 11 | isla vista
# Processing Record 7 of Set 11 | ajdabiya
# Processing Record 8 of Set 11 | chancay
# Processing Record 9 of Set 11 | kamenka
# Processing Record 10 of Set 11 | tabas
# Processing Record 11 of Set 11 | villaviciosa
# Processing Record 12 of Set 11 | minden
# Processing Record 13 of Set 11 | bhinmal
# Processing Record 14 of Set 11 | strezhevoy
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | mahibadhoo
# Processing Record 17 of Set 11 | erdenet
# Processing Record 18 of Set 11 | tahe
# Processing Record 19 of Set 11 | muhos
# Processing Record 20 of Set 11 | taoudenni
# Processing Record 21 of Set 11 | jacareacanga
# Processing Record 22 of Set 11 | port hardy
# Processing Record 23 of Set 11 | nuuk
# Processing Record 24 of Set 11 | agadez
# Processing Record 25 of Set 11 | kunming
# Processing Record 26 of Set 11 | bokspits
# Processing Record 27 of Set 11 | pecos
# Processing Record 28 of Set 11 | harper
# Processing Record 29 of Set 11 | mayo
# Processing Record 30 of Set 11 | manono
# Processing Record 31 of Set 11 | murray bridge
# Processing Record 32 of Set 11 | ilhabela
# Processing Record 33 of Set 11 | chagda
# Processing Record 34 of Set 11 | jinchang
# Processing Record 35 of Set 11 | kaohsiung
# Processing Record 36 of Set 11 | ulladulla
# Processing Record 37 of Set 11 | druzhba
# Processing Record 38 of Set 11 | tabiauea
# Processing Record 39 of Set 11 | guaymas
# Processing Record 40 of Set 11 | narasannapeta
# Processing Record 41 of Set 11 | prince rupert
# Processing Record 42 of Set 11 | port hedland
# Processing Record 43 of Set 11 | bernardino de campos
# Processing Record 44 of Set 11 | langham
# Processing Record 45 of Set 11 | jiazi
# Processing Record 46 of Set 11 | armacao dos buzios
# Processing Record 47 of Set 11 | washougal
# Processing Record 48 of Set 11 | waddan
# Processing Record 49 of Set 11 | polonnaruwa
# Processing Record 1 of Set 12 | aquiraz
# Processing Record 2 of Set 12 | miri
# Processing Record 3 of Set 12 | ngukurr
# Processing Record 4 of Set 12 | huarmey
# Processing Record 5 of Set 12 | goias
# Processing Record 6 of Set 12 | sao miguel do araguaia
# Processing Record 7 of Set 12 | estelle
# Processing Record 8 of Set 12 | the valley
# Processing Record 9 of Set 12 | samusu
# Processing Record 10 of Set 12 | abu dhabi
# Processing Record 11 of Set 12 | shimanovsk
# Processing Record 12 of Set 12 | visby
# Processing Record 13 of Set 12 | zarubino
# Processing Record 14 of Set 12 | norman wells
# Processing Record 15 of Set 12 | nova odesa
# Processing Record 16 of Set 12 | neiafu
# Processing Record 17 of Set 12 | asfi
# Processing Record 18 of Set 12 | khandyga
# Processing Record 19 of Set 12 | kuryk
# Processing Record 20 of Set 12 | krasnozerskoye
# Processing Record 21 of Set 12 | fevralsk
# Processing Record 22 of Set 12 | saurimo
# Processing Record 23 of Set 12 | dicabisagan
# Processing Record 24 of Set 12 | tual
# Processing Record 25 of Set 12 | praia
# Processing Record 26 of Set 12 | nadym
# Processing Record 27 of Set 12 | dosso
# Processing Record 28 of Set 12 | brumado
# Processing Record 29 of Set 12 | coquimbo
# Processing Record 30 of Set 12 | bien hoa
# Processing Record 31 of Set 12 | quesnel
# Processing Record 32 of Set 12 | quime
# Processing Record 33 of Set 12 | sayyan
# Processing Record 34 of Set 12 | sabang
# Processing Record 35 of Set 12 | matara
# Processing Record 36 of Set 12 | ituni
# Processing Record 37 of Set 12 | zurrieq
# Processing Record 38 of Set 12 | yabassi
# Processing Record 39 of Set 12 | la ronge
# Processing Record 40 of Set 12 | charters towers
# Processing Record 41 of Set 12 | teacapan
# Processing Record 42 of Set 12 | ust-kuyga
# Processing Record 43 of Set 12 | terney
# Processing Record 44 of Set 12 | sidi qasim
# Processing Record 45 of Set 12 | wailuku
# Processing Record 46 of Set 12 | watertown
# Processing Record 47 of Set 12 | north bend
# Processing Record 48 of Set 12 | nishihara
# Processing Record 49 of Set 12 | gandajika
# Processing Record 1 of Set 13 | alashtar
# Processing Record 2 of Set 13 | surman
# Processing Record 3 of Set 13 | roald
# Processing Record 4 of Set 13 | boguchany
# Processing Record 5 of Set 13 | esperance

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
